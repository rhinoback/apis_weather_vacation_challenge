# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#pip install py gmaps

# %%
# Dependencies and Setup
# %matplotlib notebook

import gmaps
import pandas as pd
import gmaps.datasets
import csv
import numpy as np
import requests
import time
from scipy.stats import linregress
import matplotlib.pyplot as plt
from scipy import stats
import ipywidgets as widgets
import logging
logging.basicConfig(level=logging.DEBUG)
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy



# Google developer API key
from api_keys_6 import g_key




#weather_data_short_load= "weather_data_short.csv"
#wds_df = pd.read_csv(weather_data_short_load)
# Out:
# DEBUG:matplotlib.pyplot:Loaded backend nbAgg version unknown.

# %%
weather_data_to_load= "weather_data.csv"
weather_data = pd.read_csv(weather_data_to_load)
#pip install py gmaps

# %%
weather_data
# Out:
#              citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0                Lebu      CL -37.6167  -73.6500  17.99     17.99           1
# 1           Jamestown      US  42.0970  -79.2353  -3.10     -2.78          90
# 2              Barrow      US  71.2906 -156.7887 -23.00    -23.00          90
# 3             Dunedin      NZ -45.8742  170.5036   9.96      9.96          97
# 4            Tasiilaq      GL  65.6145  -37.6368   4.00      4.00          75
# ..                ...     ...      ...       ...    ...       ...         ...
# 547  Muroto-misakicho      JP  33.2833  134.1500  16.31     16.31          92
# 548             Tabas      IR  33.5959   56.9244  20.02     20.02          32
# 549         Boa Vista      BR   2.8197  -60.6733  32.00     32.00          75
# 550             Roura      GF   4.7263  -52.3274  26.55     27.22          90
# 551          Imbituba      BR -28.2400  -48.6703  27.00     27.00          75
#
# ...

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather_data.head()
# Out:
#     citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0       Lebu      CL -37.6167  -73.6500  17.99     17.99           1
# 1  Jamestown      US  42.0970  -79.2353  -3.10     -2.78          90
# 2     Barrow      US  71.2906 -156.7887 -23.00    -23.00          90
# 3    Dunedin      NZ -45.8742  170.5036   9.96      9.96          97
# 4   Tasiilaq      GL  65.6145  -37.6368   4.00      4.00          75
#
#    humidity  windspeed        date
# 0        73       4.52  1614967499
# 1        91       8.32  1614967499
# 2        64       9.77  1614967500
# 3        81       2.14  1614967500
# 4        81       5.66  1614968031

# %%
#This smaller data set is to be used for debugging and trial
# Out:
# 28

# %%
vfd= weather_data.head()

# %%
vfd
# Out:
#     citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0       Lebu      CL -37.6167  -73.6500  17.99     17.99           1
# 1  Jamestown      US  42.0970  -79.2353  -3.10     -2.78          90
# 2     Barrow      US  71.2906 -156.7887 -23.00    -23.00          90
# 3    Dunedin      NZ -45.8742  170.5036   9.96      9.96          97
# 4   Tasiilaq      GL  65.6145  -37.6368   4.00      4.00          75
#
#    humidity  windspeed        date
# 0        73       4.52  1614967499
# 1        91       8.32  1614967499
# 2        64       9.77  1614967500
# 3        81       2.14  1614967500
# 4        81       5.66  1614968031

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#Configure gmaps
import gmaps
gmaps.configure(api_key=g_key)

# %%
#plocations = vfd[["lat", "lon"]].astype(float)

#prating = vfd["humidity"]

# %%
 # Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=100,
                                 point_radius=5)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
vacay_data= weather_data
vacay_data
# Out:
#              citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0                Lebu      CL -37.6167  -73.6500  17.99     17.99           1
# 1           Jamestown      US  42.0970  -79.2353  -3.10     -2.78          90
# 2              Barrow      US  71.2906 -156.7887 -23.00    -23.00          90
# 3             Dunedin      NZ -45.8742  170.5036   9.96      9.96          97
# 4            Tasiilaq      GL  65.6145  -37.6368   4.00      4.00          75
# ..                ...     ...      ...       ...    ...       ...         ...
# 547  Muroto-misakicho      JP  33.2833  134.1500  16.31     16.31          92
# 548             Tabas      IR  33.5959   56.9244  20.02     20.02          32
# 549         Boa Vista      BR   2.8197  -60.6733  32.00     32.00          75
# 550             Roura      GF   4.7263  -52.3274  26.55     27.22          90
# 551          Imbituba      BR -28.2400  -48.6703  27.00     27.00          75
#
# ...

# %%
locations = vacay_data[["lat", "lon"]].astype(float)

rating = vacay_data["humidity"]


 # Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=100,
                                 point_radius=4)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#vac_lon_coords=vfd['lon'].tolist()
#vac_lon_coords
#vac_lat_coords=vfd['lat'].tolist()
#vac_lat_coords

# %%
locations = vacay_data[["lat", "lon"]].astype(float)

rating = vacay_data["humidity"]


 # Plot Heatmap
fig = gmaps.figure(map_type='HYBRID')

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=100,
                                 point_radius=2)
# Add layer
fig.add_layer(heat_layer)

# Display figure
fig

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
vacay_filter_df=weather_data.loc[(weather_data["temp_max"]<30) & (weather_data["temp_max"]>19)& (weather_data["cloudiness"]==0)& (weather_data["windspeed"]<10)]
len(vacay_filter_df)
# Out:
# 39

# %%
vacay_filter_df.to_csv('perfect_vacation_filtered_data.csv', index=False, header=True)

# %%
vacay_filter_df
# Out:
#            citylist country      lat       lon   temp  temp_max  cloudiness  \
# 29        Cape Town      ZA -33.9258   18.4232  20.60     22.78           0
# 55        Carnarvon      AU -24.8667  113.6333  24.00     24.00           0
# 60            Umluj      SA  25.0213   37.2685  22.44     22.44           0
# 63            Ancud      CL -41.8697  -73.8203  24.21     25.00           0
# 80         Hermanus      ZA -34.4187   19.2345  21.11     21.11           0
# 85      East London      ZA -33.0153   27.9116  20.00     20.00           0
# 98         Rach Gia      VN  10.0167  105.0833  24.00     24.00           0
# 112        Saldanha      ZA -33.0117   17.9442  23.00     23.00           0
# 113            Qena      EG  26.1615   32.7183  21.00     21.00           0
# 116  Guerrero Negro      MX  27.9769 -114.0611  21.19     21.19           0
# 118           Mongo      TD  12.1844   18.6930  29.50     29.50           0
# ...

# %%
#remove highest humidty locations for a more pleasurable vacation
#perfect_vacation_df=weather_data.loc[(weather_data["temp_max"]<30) & (weather_data["temp_max"]>20)& (weather_data["cloudiness"]==0)& (weather_data["windspeed"]<10)& (weather_data["humidity"]<70)]
#len(perfect_vacation_df)

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#NaN = np.nan
#df["column3"] = NaN
#pv_df['new_column']
#pv_df['colum11']
hotel_df= vacay_filter_df

# %%
# Google developer API key
from config import g_key

# %% [markdown]
# ###Hotel Map
#
# #Store into variable named hotel_df
# hotel_df= locations = pv_df[["lat", "lon"]].astype(float)
#
# rating = pv_df["humidity"]
# # Plot Heatmap
# fig = gmaps.figure()
#
# # Create heat layer
# heat_layer = gmaps.heatmap_layer(locations, weights=rating,
#                                  dissipating=False, max_intensity=10,
#                                  point_radius=2)
#
# # Add layer
# fig.add_layer(heat_layer)
#
# # Display figure
# fig

# %%
#pv_df2=pv_df

# %%
#pv_df2["Hotel Name"]=""
#pv_df2
# Out:
# <ipython-input-20-b18d459c3b2e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pv_df2["Hotel Name"]=""
#                  citylist country      lat      lon   temp  temp_max  \
# 110                 Ancud      CL -41.8697 -73.8203  20.13     21.00
# 125              Beïnamar      TD   8.6698  15.3813  25.04     25.04
# 181                   Sur      OM  22.5667  59.5289  20.64     20.64
# 183          Río Gallegos      AR -51.6226 -69.2181  24.00     24.00
# 214                Camaná      PE -16.6228 -72.7111  24.88     24.88
# 294                  Adré      TD  13.4667  22.2000  21.77     21.77
# 300  Makkah al Mukarramah      SA  21.4267  39.8261  25.00     25.00
# ...

# %%
hotel_df
# Out:
#            citylist country      lat       lon   temp  temp_max  cloudiness  \
# 29        Cape Town      ZA -33.9258   18.4232  20.60     22.78           0
# 55        Carnarvon      AU -24.8667  113.6333  24.00     24.00           0
# 60            Umluj      SA  25.0213   37.2685  22.44     22.44           0
# 63            Ancud      CL -41.8697  -73.8203  24.21     25.00           0
# 80         Hermanus      ZA -34.4187   19.2345  21.11     21.11           0
# 85      East London      ZA -33.0153   27.9116  20.00     20.00           0
# 98         Rach Gia      VN  10.0167  105.0833  24.00     24.00           0
# 112        Saldanha      ZA -33.0117   17.9442  23.00     23.00           0
# 113            Qena      EG  26.1615   32.7183  21.00     21.00           0
# 116  Guerrero Negro      MX  27.9769 -114.0611  21.19     21.19           0
# 118           Mongo      TD  12.1844   18.6930  29.50     29.50           0
# ...

# %%
#hotel_df
#Add a "Hotel Name" column to the DataFrame.
#>>> df["C"] = ""
hotel_df["Hotel Name"]=""
hotel_df
# Out:
# <ipython-input-34-d3be8de8d194>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["Hotel Name"]=""
#            citylist country      lat       lon   temp  temp_max  cloudiness  \
# 29        Cape Town      ZA -33.9258   18.4232  20.60     22.78           0
# 55        Carnarvon      AU -24.8667  113.6333  24.00     24.00           0
# 60            Umluj      SA  25.0213   37.2685  22.44     22.44           0
# 63            Ancud      CL -41.8697  -73.8203  24.21     25.00           0
# 80         Hermanus      ZA -34.4187   19.2345  21.11     21.11           0
# 85      East London      ZA -33.0153   27.9116  20.00     20.00           0
# 98         Rach Gia      VN  10.0167  105.0833  24.00     24.00           0
# ...

# %%
# Google developer API key
#from config import g_key

# %%
params = {
    "radius": 5000,
    "types": "Hotel",
    "keyword": "Hotel",
    "key": g_key
}

for index, row in hotel_df.iterrows():
    # get lat, lng from df
    lats = row["lat"]
    lons = row["lon"]    
    # change location each iteration while leaving original params in place
    params["location"] = f"{lats},{lons}"    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"    
    # make request and print url
    name_address = requests.get(base_url, params=params)
    #print the name_address url, avoid doing for public github repos in order to avoid exposing key
    print(name_address.url)  
    # convert to json
    name_address = name_address.json()
    #print(json.dumps(name_address, indent=4, sort_keys=True))    
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["results"][0]["name"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://maps.googleapis.com:443 "GET /maps/api/place/nearbysearch/json?radius=5000&types=Hotel&keyword=Hotel&key=AIzaSyBY7hoCeoa6tnTT8n-kaD-C-JhJmsS5bHo&location=-33.9258%2C18.4232 HTTP/1.1" 200 6850
# /Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): maps.googleapis.com:443
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=Hotel&keyword=Hotel&key=AIzaSyBY7hoCeoa6tnTT8n-kaD-C-JhJmsS5bHo&location=-33.9258%2C18.4232
# ...

# %%
hotel_df
# Out:
#            citylist country      lat       lon   temp  temp_max  cloudiness  \
# 29        Cape Town      ZA -33.9258   18.4232  20.60     22.78           0
# 55        Carnarvon      AU -24.8667  113.6333  24.00     24.00           0
# 60            Umluj      SA  25.0213   37.2685  22.44     22.44           0
# 63            Ancud      CL -41.8697  -73.8203  24.21     25.00           0
# 80         Hermanus      ZA -34.4187   19.2345  21.11     21.11           0
# 85      East London      ZA -33.0153   27.9116  20.00     20.00           0
# 98         Rach Gia      VN  10.0167  105.0833  24.00     24.00           0
# 112        Saldanha      ZA -33.0117   17.9442  23.00     23.00           0
# 113            Qena      EG  26.1615   32.7183  21.00     21.00           0
# 116  Guerrero Negro      MX  27.9769 -114.0611  21.19     21.19           0
# 118           Mongo      TD  12.1844   18.6930  29.50     29.50           0
# ...

# %%
hotel_df
# Out:
#            citylist country      lat       lon   temp  temp_max  cloudiness  \
# 29        Cape Town      ZA -33.9258   18.4232  20.60     22.78           0
# 55        Carnarvon      AU -24.8667  113.6333  24.00     24.00           0
# 60            Umluj      SA  25.0213   37.2685  22.44     22.44           0
# 63            Ancud      CL -41.8697  -73.8203  24.21     25.00           0
# 80         Hermanus      ZA -34.4187   19.2345  21.11     21.11           0
# 85      East London      ZA -33.0153   27.9116  20.00     20.00           0
# 98         Rach Gia      VN  10.0167  105.0833  24.00     24.00           0
# 112        Saldanha      ZA -33.0117   17.9442  23.00     23.00           0
# 113            Qena      EG  26.1615   32.7183  21.00     21.00           0
# 116  Guerrero Negro      MX  27.9769 -114.0611  21.19     21.19           0
# 118           Mongo      TD  12.1844   18.6930  29.50     29.50           0
# ...

# %%
hotel_df_clean=hotel_df.drop([118,162,204,292,314,479,514])

# %%
hotel_df_clean
# Out:
#            citylist country      lat       lon   temp  temp_max  cloudiness  \
# 29        Cape Town      ZA -33.9258   18.4232  20.60     22.78           0
# 55        Carnarvon      AU -24.8667  113.6333  24.00     24.00           0
# 60            Umluj      SA  25.0213   37.2685  22.44     22.44           0
# 63            Ancud      CL -41.8697  -73.8203  24.21     25.00           0
# 80         Hermanus      ZA -34.4187   19.2345  21.11     21.11           0
# 85      East London      ZA -33.0153   27.9116  20.00     20.00           0
# 98         Rach Gia      VN  10.0167  105.0833  24.00     24.00           0
# 112        Saldanha      ZA -33.0117   17.9442  23.00     23.00           0
# 113            Qena      EG  26.1615   32.7183  21.00     21.00           0
# 116  Guerrero Negro      MX  27.9769 -114.0611  21.19     21.19           0
# 130      Nouadhibou      MR  20.9310  -17.0347  21.00     21.00           0
# ...

# %%
hotel_df_clean.reset_index(drop=True, inplace=True)

# %%
hotel_df_clean
# Out:
#           citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0        Cape Town      ZA -33.9258   18.4232  20.60     22.78           0
# 1        Carnarvon      AU -24.8667  113.6333  24.00     24.00           0
# 2            Umluj      SA  25.0213   37.2685  22.44     22.44           0
# 3            Ancud      CL -41.8697  -73.8203  24.21     25.00           0
# 4         Hermanus      ZA -34.4187   19.2345  21.11     21.11           0
# 5      East London      ZA -33.0153   27.9116  20.00     20.00           0
# 6         Rach Gia      VN  10.0167  105.0833  24.00     24.00           0
# 7         Saldanha      ZA -33.0117   17.9442  23.00     23.00           0
# 8             Qena      EG  26.1615   32.7183  21.00     21.00           0
# 9   Guerrero Negro      MX  27.9769 -114.0611  21.19     21.19           0
# 10      Nouadhibou      MR  20.9310  -17.0347  21.00     21.00           0
# ...

# %%
hotel_df_clean.to_csv('hotel_data.csv', index = False)

# %%
hd=hotel_df_clean
hd
# Out:
#           citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0        Cape Town      ZA -33.9258   18.4232  20.60     22.78           0
# 1        Carnarvon      AU -24.8667  113.6333  24.00     24.00           0
# 2            Umluj      SA  25.0213   37.2685  22.44     22.44           0
# 3            Ancud      CL -41.8697  -73.8203  24.21     25.00           0
# 4         Hermanus      ZA -34.4187   19.2345  21.11     21.11           0
# 5      East London      ZA -33.0153   27.9116  20.00     20.00           0
# 6         Rach Gia      VN  10.0167  105.0833  24.00     24.00           0
# 7         Saldanha      ZA -33.0117   17.9442  23.00     23.00           0
# 8             Qena      EG  26.1615   32.7183  21.00     21.00           0
# 9   Guerrero Negro      MX  27.9769 -114.0611  21.19     21.19           0
# 10      Nouadhibou      MR  20.9310  -17.0347  21.00     21.00           0
# ...

# %%
hd.drop(columns=['hotel info'])
# Out:
#           citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0        Cape Town      ZA -33.9258   18.4232  20.60     22.78           0
# 1        Carnarvon      AU -24.8667  113.6333  24.00     24.00           0
# 2            Umluj      SA  25.0213   37.2685  22.44     22.44           0
# 3            Ancud      CL -41.8697  -73.8203  24.21     25.00           0
# 4         Hermanus      ZA -34.4187   19.2345  21.11     21.11           0
# 5      East London      ZA -33.0153   27.9116  20.00     20.00           0
# 6         Rach Gia      VN  10.0167  105.0833  24.00     24.00           0
# 7         Saldanha      ZA -33.0117   17.9442  23.00     23.00           0
# 8             Qena      EG  26.1615   32.7183  21.00     21.00           0
# 9   Guerrero Negro      MX  27.9769 -114.0611  21.19     21.19           0
# 10      Nouadhibou      MR  20.9310  -17.0347  21.00     21.00           0
# ...

# %%
 # NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{citylist}</dd>
<dt>Country</dt><dd>{country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hd.iterrows()]
locations = hd[["lat", "lon"]]

# %%
markers = gmaps.marker_layer(locations)
hotel_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=2,
    info_box_content=hotel_info
)
fig.add_layer(markers)
fig.add_layer(hotel_layer)
fig
#Perfect Vacation Destination Map for those looking for light wind, cloudless skies, and warm weather.
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
 
    # NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{citylist}</dd>
<dt>Country</dt><dd>{country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hd.iterrows()]
locations = hd[["lat", "lon"]]

# %%
markers = gmaps.marker_layer(locations)
hotel_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=2,
    info_box_content=hotel_info
    
)
fig.add_layer(markers)
fig.add_layer(hotel_layer)
fig
#Perfect Vacation Destination Map for those looking for light wind, cloudless skies, and warm weather.
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
locations = hd[["lat", "lon"]].astype(float)

rating = hd["humidity"]


 # Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=100,
                                 point_radius=4)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
hd['hotel info']= hotel_info
hd
# Out:
#           citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0        Cape Town      ZA -33.9258   18.4232  20.60     22.78           0
# 1        Carnarvon      AU -24.8667  113.6333  24.00     24.00           0
# 2            Umluj      SA  25.0213   37.2685  22.44     22.44           0
# 3            Ancud      CL -41.8697  -73.8203  24.21     25.00           0
# 4         Hermanus      ZA -34.4187   19.2345  21.11     21.11           0
# 5      East London      ZA -33.0153   27.9116  20.00     20.00           0
# 6         Rach Gia      VN  10.0167  105.0833  24.00     24.00           0
# 7         Saldanha      ZA -33.0117   17.9442  23.00     23.00           0
# 8             Qena      EG  26.1615   32.7183  21.00     21.00           0
# 9   Guerrero Negro      MX  27.9769 -114.0611  21.19     21.19           0
# 10      Nouadhibou      MR  20.9310  -17.0347  21.00     21.00           0
# ...

# %%
#locations = hd[["lat", "lon"]].astype(float)

rating = hd["humidity"]

 # Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, dissipating=False, max_intensity=100, point_radius=4)
markers = gmaps.marker_layer(locations)
hotel_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=2,
    info_box_content=hotel_info
    
)

fig.add_layer(markers)
fig.add_layer(hotel_layer)
fig.add_layer(heat_layer)   
fig
#Perfect Vacation Destination Map for those looking for light wind, cloudless skies, and warm weather.
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# #satellite
