# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# refer to this
# https://uci.bootcampcontent.com/UCI-Coding-Bootcamp/uci-irv-data-pt-12-2020-u-c/blob/master/Homework/06-Python-APIs/Instructions/starter_code/WeatherPy.ipynb

# %% [markdown]
# Your final notebook must:
#
# Randomly select at least 500 unique (non-repeat) cities based on latitude and longitude.
# Perform a weather check on each of the cities using a series of successive API calls.
# Include a print log of each city as it's being processed with the city number and city name.
# Save a CSV of all retrieved data and a PNG image for each scatter plot.

# %%
# !pip install pandas-log
# !pip install pandas-flavor
# !pip install humanize
# Out:
# Collecting pandas-log
#   Downloading pandas_log-0.1.7-py2.py3-none-any.whl (13 kB)
# Collecting humanize>=0.5.0
#   Downloading humanize-3.2.0-py3-none-any.whl (70 kB)
#      |████████████████████████████████| 70 kB 1.3 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.25.1 in /Users/crloud/opt/anaconda3/lib/python3.8/site-packages (from pandas-log) (1.0.5)
# Collecting pandas-flavor>=0.1.2
#   Downloading pandas_flavor-0.2.0-py2.py3-none-any.whl (6.6 kB)
# Requirement already satisfied: setuptools in /Users/crloud/opt/anaconda3/lib/python3.8/site-packages (from humanize>=0.5.0->pandas-log) (49.2.0.post20200714)
# Requirement already satisfied: numpy>=1.13.3 in /Users/crloud/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.1->pandas-log) (1.18.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/crloud/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.1->pandas-log) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/crloud/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.1->pandas-log) (2020.1)
# Collecting xarray
#   Downloading xarray-0.17.0-py3-none-any.whl (759 kB)
#      |████████████████████████████████| 759 kB 1.1 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /Users/crloud/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.6.1->pandas>=0.25.1->pandas-log) (1.15.0)
# ERROR: Error checking for conflicts.
# Traceback (most recent call last):
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3021, in _dep_map
#     return self.__dep_map
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3012, in _parsed_pkg_info
#     return self._pkg_info
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _pkg_info
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/commands/install.py", line 512, in _warn_about_conflicts
#     package_set, _dep_info = check_install_conflicts(to_install)
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/operations/check.py", line 114, in check_install_conflicts
#     package_set, _ = create_package_set_from_installed()
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/operations/check.py", line 53, in create_package_set_from_installed
#     package_set[name] = PackageDetails(dist.version, dist.requires())
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2736, in requires
#     dm = self._dep_map
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3023, in _dep_map
#     self.__dep_map = self._compute_dependencies()
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3032, in _compute_dependencies
#     for req in self._parsed_pkg_info.get_all('Requires-Dist') or []:
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3014, in _parsed_pkg_info
#     metadata = self.get_metadata(self.PKG_INFO)
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 1420, in get_metadata
#     value = self._get(path)
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 1616, in _get
#     with open(path, 'rb') as stream:
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/sql-0.4.0.dist-info/METADATA'
# Installing collected packages: humanize, xarray, pandas-flavor, pandas-log
# Successfully installed humanize-3.2.0 pandas-flavor-0.2.0 pandas-log-0.1.7 xarray-0.17.0
# Requirement already satisfied: pandas-flavor in /Users/crloud/opt/anaconda3/lib/python3.8/site-packages (0.2.0)
# Requirement already satisfied: pandas in /Users/crloud/opt/anaconda3/lib/python3.8/site-packages (from pandas-flavor) (1.0.5)
# Requirement already satisfied: xarray in /Users/crloud/opt/anaconda3/lib/python3.8/site-packages (from pandas-flavor) (0.17.0)
# Requirement already satisfied: numpy>=1.13.3 in /Users/crloud/opt/anaconda3/lib/python3.8/site-packages (from pandas->pandas-flavor) (1.18.5)
# Requirement already satisfied: pytz>=2017.2 in /Users/crloud/opt/anaconda3/lib/python3.8/site-packages (from pandas->pandas-flavor) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/crloud/opt/anaconda3/lib/python3.8/site-packages (from pandas->pandas-flavor) (2.8.1)
# Requirement already satisfied: setuptools>=40.4 in /Users/crloud/opt/anaconda3/lib/python3.8/site-packages (from xarray->pandas-flavor) (49.2.0.post20200714)
# Requirement already satisfied: six>=1.5 in /Users/crloud/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.6.1->pandas->pandas-flavor) (1.15.0)
# ERROR: Error checking for conflicts.
# Traceback (most recent call last):
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3021, in _dep_map
#     return self.__dep_map
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3012, in _parsed_pkg_info
#     return self._pkg_info
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _pkg_info
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/commands/install.py", line 512, in _warn_about_conflicts
#     package_set, _dep_info = check_install_conflicts(to_install)
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/operations/check.py", line 114, in check_install_conflicts
#     package_set, _ = create_package_set_from_installed()
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/operations/check.py", line 53, in create_package_set_from_installed
#     package_set[name] = PackageDetails(dist.version, dist.requires())
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2736, in requires
#     dm = self._dep_map
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3023, in _dep_map
#     self.__dep_map = self._compute_dependencies()
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3032, in _compute_dependencies
#     for req in self._parsed_pkg_info.get_all('Requires-Dist') or []:
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3014, in _parsed_pkg_info
#     metadata = self.get_metadata(self.PKG_INFO)
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 1420, in get_metadata
#     value = self._get(path)
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 1616, in _get
#     with open(path, 'rb') as stream:
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/sql-0.4.0.dist-info/METADATA'
# Requirement already satisfied: humanize in /Users/crloud/opt/anaconda3/lib/python3.8/site-packages (3.2.0)
# Requirement already satisfied: setuptools in /Users/crloud/opt/anaconda3/lib/python3.8/site-packages (from humanize) (49.2.0.post20200714)
# ERROR: Error checking for conflicts.
# Traceback (most recent call last):
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3021, in _dep_map
#     return self.__dep_map
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3012, in _parsed_pkg_info
#     return self._pkg_info
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _pkg_info
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/commands/install.py", line 512, in _warn_about_conflicts
#     package_set, _dep_info = check_install_conflicts(to_install)
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/operations/check.py", line 114, in check_install_conflicts
#     package_set, _ = create_package_set_from_installed()
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/operations/check.py", line 53, in create_package_set_from_installed
#     package_set[name] = PackageDetails(dist.version, dist.requires())
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2736, in requires
#     dm = self._dep_map
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3023, in _dep_map
#     self.__dep_map = self._compute_dependencies()
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3032, in _compute_dependencies
#     for req in self._parsed_pkg_info.get_all('Requires-Dist') or []:
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3014, in _parsed_pkg_info
#     metadata = self.get_metadata(self.PKG_INFO)
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 1420, in get_metadata
#     value = self._get(path)
#   File "/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 1616, in _get
#     with open(path, 'rb') as stream:
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/crloud/opt/anaconda3/lib/python3.8/site-packages/sql-0.4.0.dist-info/METADATA'

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
from scipy.stats import linregress
import csv
import matplotlib.pyplot as plt
from scipy import stats
#import logging
#logging.basicConfig(level=logging.DEBUG)
import time
import datetime as dt
#    t1 = dt. datetime. strptime('12:00:00', '%H:%M:%S')
#    t2 = dt. datetime. strptime('02:00:00', '%H:%M:%S')
#    time_zero = dt. datetime. strptime('00:00:00', '%H:%M:%S')
#    print((t1 - time_zero + t2). time())

# Import API key
from api_keys_6 import weather_api_key
api_key = weather_api_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
#weather_data_to_load= "weatherpy_data.csv"
#weather_data = pd.read_csv(weather_data_to_load)

#weather_data_print_example= "weather_data_print.csv"
#weather_data_print = pd.read_csv(weather_data_print_example)

# %%
output_data_file = "output_data/cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)


 # Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

query_url = f"{url}appid={api_key}&units={units}&q="

# %% [markdown]
# ## Generate Cities List

# %% [markdown]
#  Extract latitude and longitude
# lats = geo_data["results"][0]["geometry"]["location"]["lat"]
# lngs = geo_data["results"][0]["geometry"]["location"]["lng"]
#
# #Print the latitude and longitude
# print('''
#     City: {0}
#     Latitude: {1}
#     Longitude: {2}
#     '''.format(target_city, lat, lng))

# %%
 # List for holding lat_lngs and cities
    
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations

lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(cities)
# Out:
# ['lebu', 'jamestown', 'barrow', 'dunedin', 'tasiilaq', 'rikitea', 'navalcarnero', 'raudeberg', 'richards bay', 'kapaa', 'novoagansk', 'berlevag', 'ilulissat', 'capao da canoa', 'jiuquan', 'mirina', 'kaitangata', 'ulaangom', 'bone', 'port moresby', 'ushuaia', 'jaciara', 'thompson', 'port elizabeth', 'portland', 'ribeira grande', 'saskylakh', 'busselton', 'cidreira', 'kahului', 'cape town', 'mar del plata', 'mataura', 'ingham', 'hobart', 'barentsburg', 'punta arenas', 'ternate', 'mountain home', 'ostrovnoy', 'hithadhoo', 'narsaq', 'camacha', 'kloulklubed', 'port alfred', 'illoqqortoormiut', 'puerto ayora', 'sorong', 'yellowknife', 'upernavik', 'ouango', 'atuona', 'tabiauea', 'inndyr', 'amahai', 'airai', 'mweka', 'zolotinka', 'hilo', 'makat', 'carnarvon', 'cayenne', 'truth or consequences', 'beringovskiy', 'rosarito', 'umm lajj', 'chokurdakh', 'albany', 'sentyabrskiy', 'ancud', 'ambovombe', 'margate', 'bathsheba', 'alofi', 'hervey bay', 'nantucket', 'fairbanks', 'nobeoka', 'vaini', 'khani', 'snyder', 'watertown', 'zyryanka', 'nadadores', 'kodiak', 'klaksvik', 'hermanus', 'hegang', 'howard springs', 'fevralsk', 'tuktoyaktuk', 'ranong', 'mys shmidta', 'east london', 'nikolskoye', 'ponta do sol', 'butaritari', 'tavda', 'hay river', 'beira', 'gornopravdinsk', 'bintulu', 'nome', 'aligudarz', 'bluff', 'avera', 'rach gia', 'gravdal', 'shihezi', 'djibo', 'lavrentiya', 'taolanaro', 'bonavista', 'sitka', 'lata', 'paciran', 'coahuayana', 'tiksi', 'palabuhanratu', 'liwale', 'dikson', 'kuala terengganu', 'saldanha', 'qena', 'hasaki', 'tumannyy', 'khatanga', 'guerrero negro', 'bafq', 'mongo', 'kodinsk', 'dzhebariki-khaya', 'gryazi', 'naruto', 'machali', 'quatre cocos', 'chapais', 'calamar', 'kisangani', 'qaanaaq', 'esperance', 'nouadhibou', 'luebo', 'tuatapere', 'guatire', 'cabedelo', 'kalemie', 'kijang', 'khanpur', 'llanes', 'tawkar', 'chumikan', 'toliary', 'houma', 'maldonado', 'ilhabela', 'pemangkat', 'karachev', 'iqaluit', 'honiara', 'beloha', 'saleaula', 'simpang', 'svetlogorsk', 'gimli', 'severo-kurilsk', 'osoyoos', 'new norfolk', 'simao', 'avarua', 'candawaga', 'kieta', 'olafsvik', 'vaitupu', 'kavieng', 'nizhneyansk', 'bac lieu', 'provideniya', 'kristiansund', 'adrar', 'shingu', 'nhulunbuy', 'thabazimbi', 'attawapiskat', 'sangar', 'west richland', 'kralendijk', 'san isidro', 'cockburn town', 'ithaki', 'sakakah', 'saint anthony', 'longyearbyen', 'praia da vitoria', 'axim', 'enshi', 'cherskiy', 'banjar', 'bambanglipuro', 'porto novo', 'lingao', 'asayita', 'henties bay', 'bredasdorp', 'anadyr', 'eureka', 'belushya guba', 'zaragoza', 'alice springs', 'la ronge', 'soe', 'zhaoyuan', 'sao joao da barra', 'khandyga', 'bengkulu', 'miraflores', 'omsukchan', 'mehamn', 'loreto', 'oktyabrskiy', 'dakar', 'mokhsogollokh', 'mount gambier', 'hagi', 'bitkine', 'srednekolymsk', 'bandarbeyla', 'firminopolis', 'kynsperk nad ohri', 'phan thiet', 'vila velha', 'lagoa', 'san cristobal', 'lompoc', 'bulgan', 'jiblah', 'broome', 'zhigansk', 'haines junction', 'fukue', 'tura', 'matadi', 'marcona', 'mosquera', 'saint george', 'tomatlan', 'chuy', 'rungata', 'coquimbo', 'san vicente de chucuri', 'san luis', 'pacific grove', 'sandwick', 'pingliang', 'sidi ali', 'tarakan', 'teguldet', 'qasigiannguit', 'makhalino', 'cap malheureux', 'zarasai', 'sabaneta', 'nanortalik', 'tecoanapa', 'sungaipenuh', 'petropavlovsk-kamchatskiy', 'sivaki', 'souillac', 'vredendal', 'pandamatenga', 'mathathane', 'eyl', 'veraval', 'neiafu', 'palmer', 'uyemskiy', 'akyab', 'saint-philippe', 'kadykchan', 'hualmay', 'pevek', 'lasa', 'ambatofinandrahana', 'sorvag', 'itarema', 'sarangani', 'troitsko-pechorsk', 'alto araguaia', 'myslenice', 'kavaratti', 'lephepe', 'razole', 'poum', 'arlit', 'namibe', 'geraldton', 'lorengau', 'port blair', 'muisne', 'cienaga de oro', 'sestu', 'sabang', 'poplar bluff', 'te anau', 'bairnsdale', 'norton shores', 'vieux-habitants', 'georgetown', 'bilibino', 'solnechnyy', 'floro', 'negele', 'antigonish', 'victoria', 'bambous virieux', 'ahipara', 'burica', 'duz', 'maridi', ' ...

# %%
print(cities)
# Out:
# 600

# %%
type(lat_lngs)
# Out:
# zip

# %%
print(cities[0:5])
# Out:
# ['lebu', 'jamestown', 'barrow', 'dunedin', 'tasiilaq']

# %%
trial=cities[0:5]
trial
# Out:
# ['lebu', 'jamestown', 'barrow', 'dunedin', 'tasiilaq']

# %%
country= []
lat= []
lon= []
temp= []
temp_max= []
cloudiness= []
humidity= []
date= []
citylist= []
windspeed=[]

# %%
for city in trial:
    try:
        response = requests.get(query_url + city).json()
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        lon.append(response['coord']['lon'])
        lat.append(response['coord']['lat'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        citylist.append(response['name'])
        windspeed.append(response['wind']['speed'])
    except (KeyError):
        print('working through to next data...')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=lebu HTTP/1.1" 200 479
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=jamestown HTTP/1.1" 200 469
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=barrow HTTP/1.1" 200 461
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=dunedin HTTP/1.1" 200 484
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=tasiilaq HTTP/1.1" 200 459

# %%
   weather_dict_trial = {
    "citylist": citylist,
    "country": country, 
    "lat": lat,
    "lon": lon,
    "temp": temp,
    "temp_max": temp_max,
    "cloudiness": cloudiness,
    "humidity": humidity,
    "windspeed": windspeed,
    "date": date,
    
}

# %%
weather_data_trial = pd.DataFrame(weather_dict_trial)
weather_data_trial
# Out:
#     citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0       Lebu      CL -37.6167  -73.6500  17.99     17.99           1
# 1  Jamestown      US  42.0970  -79.2353  -3.10     -2.78          90
# 2     Barrow      US  71.2906 -156.7887 -23.00    -23.00          90
# 3    Dunedin      NZ -45.8742  170.5036   9.96      9.96          97
# 4   Tasiilaq      GL  65.6145  -37.6368   4.00      4.00          75
#
#    humidity  windspeed        date
# 0        73       4.52  1614967499
# 1        91       8.32  1614967499
# 2        64       9.77  1614967500
# 3        81       2.14  1614967500
# 4        81       5.66  1614967501

# %% [markdown]
# ### Clean_Run_API_Calls

# %%
len(cities)
# Out:
# 600

# %%
country= []
lat= []
lon= []
temp= []
temp_max= []
cloudiness= []
humidity= []
date= []
citylist= []
windspeed=[]

# %%
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        lon.append(response['coord']['lon'])
        lat.append(response['coord']['lat'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        citylist.append(response['name'])
        windspeed.append(response['wind']['speed'])
    except (KeyError):
        print('working through to next data...')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=lebu HTTP/1.1" 200 479
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=jamestown HTTP/1.1" 200 469
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=barrow HTTP/1.1" 200 461
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=dunedin HTTP/1.1" 200 484
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=tasiilaq HTTP/1.1" 200 459
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=rikitea HTTP/1.1" 200 485
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=navalcarnero HTTP/1.1" 200 467
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=raudeberg HTTP/1.1" 200 473
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=richards%20bay HTTP/1.1" 200 504
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kapaa HTTP/1.1" 200 484
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=novoagansk HTTP/1.1" 200 490
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=berlevag HTTP/1.1" 200 462
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=ilulissat HTTP/1.1" 200 463
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=capao%20da%20canoa HTTP/1.1" 200 498
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=jiuquan HTTP/1.1" 200 485
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=mirina HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kaitangata HTTP/1.1" 200 487
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=ulaangom HTTP/1.1" 200 488
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=bone HTTP/1.1" 200 462
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=port%20moresby HTTP/1.1" 200 469
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=ushuaia HTTP/1.1" 200 460
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=jaciara HTTP/1.1" 200 490
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=thompson HTTP/1.1" 200 458
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=port%20elizabeth HTTP/1.1" 200 461
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=portland HTTP/1.1" 200 488
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=ribeira%20grande HTTP/1.1" 200 464
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=saskylakh HTTP/1.1" 200 487
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=busselton HTTP/1.1" 200 479
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=cidreira HTTP/1.1" 200 493
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kahului HTTP/1.1" 200 482
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=cape%20town HTTP/1.1" 200 462
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=mar%20del%20plata HTTP/1.1" 200 491
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=mataura HTTP/1.1" 200 470
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=ingham HTTP/1.1" 200 478
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=hobart HTTP/1.1" 200 464
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=barentsburg HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=punta%20arenas HTTP/1.1" 200 463
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=ternate HTTP/1.1" 200 482
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=mountain%20home HTTP/1.1" 200 476
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=ostrovnoy HTTP/1.1" 200 494
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=hithadhoo HTTP/1.1" 200 480
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=narsaq HTTP/1.1" 200 451
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=camacha HTTP/1.1" 200 455
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kloulklubed HTTP/1.1" 200 465
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=port%20alfred HTTP/1.1" 200 460
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=illoqqortoormiut HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=puerto%20ayora HTTP/1.1" 200 488
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=sorong HTTP/1.1" 200 499
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=yellowknife HTTP/1.1" 200 461
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=upernavik HTTP/1.1" 200 498
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=ouango HTTP/1.1" 200 481
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=atuona HTTP/1.1" 200 488
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=tabiauea HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=inndyr HTTP/1.1" 200 479
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=amahai HTTP/1.1" 200 489
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=airai HTTP/1.1" 200 482
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=mweka HTTP/1.1" 200 478
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=zolotinka HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=hilo HTTP/1.1" 200 468
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=makat HTTP/1.1" 200 481
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=carnarvon HTTP/1.1" 200 460
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=cayenne HTTP/1.1" 200 468
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=truth%20or%20consequences HTTP/1.1" 200 489
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=beringovskiy HTTP/1.1" 200 495
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=rosarito HTTP/1.1" 200 463
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=umm%20lajj HTTP/1.1" 200 478
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=chokurdakh HTTP/1.1" 200 507
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=albany HTTP/1.1" 200 484
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=sentyabrskiy HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=ancud HTTP/1.1" 200 463
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=ambovombe HTTP/1.1" 200 483
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=margate HTTP/1.1" 200 477
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=bathsheba HTTP/1.1" 200 469
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=alofi HTTP/1.1" 200 468
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=hervey%20bay HTTP/1.1" 200 472
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=nantucket HTTP/1.1" 200 476
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=fairbanks HTTP/1.1" 200 475
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=nobeoka HTTP/1.1" 200 487
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=vaini HTTP/1.1" 200 458
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=khani HTTP/1.1" 200 447
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=snyder HTTP/1.1" 200 479
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=watertown HTTP/1.1" 200 475
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=zyryanka HTTP/1.1" 200 490
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=nadadores HTTP/1.1" 200 465
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kodiak HTTP/1.1" 200 609
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=klaksvik HTTP/1.1" 200 456
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=hermanus HTTP/1.1" 200 480
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=hegang HTTP/1.1" 200 482
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=howard%20springs HTTP/1.1" 200 478
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=fevralsk HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=tuktoyaktuk HTTP/1.1" 200 472
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=ranong HTTP/1.1" 200 482
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=mys%20shmidta HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=east%20london HTTP/1.1" 200 460
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=nikolskoye HTTP/1.1" 200 468
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=ponta%20do%20sol HTTP/1.1" 200 483
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=butaritari HTTP/1.1" 200 492
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=tavda HTTP/1.1" 200 485
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=hay%20river HTTP/1.1" 200 470
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=beira HTTP/1.1" 200 480
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=gornopravdinsk HTTP/1.1" 200 489
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=bintulu HTTP/1.1" 200 471
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=nome HTTP/1.1" 200 485
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=aligudarz HTTP/1.1" 200 479
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=bluff HTTP/1.1" 200 466
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=avera HTTP/1.1" 200 458
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=rach%20gia HTTP/1.1" 200 457
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=gravdal HTTP/1.1" 200 470
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=shihezi HTTP/1.1" 200 481
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=djibo HTTP/1.1" 200 473
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=lavrentiya HTTP/1.1" 200 486
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=taolanaro HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=bonavista HTTP/1.1" 200 461
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=sitka HTTP/1.1" 200 478
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=lata HTTP/1.1" 200 479
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=paciran HTTP/1.1" 200 505
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=coahuayana HTTP/1.1" 200 467
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=tiksi HTTP/1.1" 200 490
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=palabuhanratu HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=liwale HTTP/1.1" 200 497
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=dikson HTTP/1.1" 200 489
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kuala%20terengganu HTTP/1.1" 200 479
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=saldanha HTTP/1.1" 200 457
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=qena HTTP/1.1" 200 451
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=hasaki HTTP/1.1" 200 450
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=tumannyy HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=khatanga HTTP/1.1" 200 488
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=guerrero%20negro HTTP/1.1" 200 491
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=bafq HTTP/1.1" 200 483
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=mongo HTTP/1.1" 200 472
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kodinsk HTTP/1.1" 200 493
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=dzhebariki-khaya HTTP/1.1" 200 499
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=gryazi HTTP/1.1" 200 482
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=naruto HTTP/1.1" 200 482
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=machali HTTP/1.1" 200 459
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=quatre%20cocos HTTP/1.1" 200 465
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=chapais HTTP/1.1" 200 482
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=calamar HTTP/1.1" 200 461
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kisangani HTTP/1.1" 200 481
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=qaanaaq HTTP/1.1" 200 485
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=esperance HTTP/1.1" 200 465
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=nouadhibou HTTP/1.1" 200 447
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=luebo HTTP/1.1" 200 480
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=tuatapere HTTP/1.1" 200 486
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=guatire HTTP/1.1" 200 469
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=cabedelo HTTP/1.1" 200 465
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kalemie HTTP/1.1" 200 481
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kijang HTTP/1.1" 200 454
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=khanpur HTTP/1.1" 200 480
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=llanes HTTP/1.1" 200 472
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=tawkar HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=chumikan HTTP/1.1" 200 489
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=toliary HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=houma HTTP/1.1" 200 474
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=maldonado HTTP/1.1" 200 489
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=ilhabela HTTP/1.1" 200 491
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=pemangkat HTTP/1.1" 200 502
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=karachev HTTP/1.1" 200 488
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=iqaluit HTTP/1.1" 200 468
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=honiara HTTP/1.1" 200 504
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=beloha HTTP/1.1" 200 479
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=saleaula HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=simpang HTTP/1.1" 200 485
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=svetlogorsk HTTP/1.1" 200 496
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=gimli HTTP/1.1" 200 462
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=severo-kurilsk HTTP/1.1" 200 506
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=osoyoos HTTP/1.1" 200 462
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=new%20norfolk HTTP/1.1" 200 469
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=simao HTTP/1.1" 200 478
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=avarua HTTP/1.1" 200 467
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=candawaga HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kieta HTTP/1.1" 200 500
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=olafsvik HTTP/1.1" 200 484
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=vaitupu HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kavieng HTTP/1.1" 200 490
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=nizhneyansk HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=bac%20lieu HTTP/1.1" 200 477
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=provideniya HTTP/1.1" 200 503
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kristiansund HTTP/1.1" 200 491
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=adrar HTTP/1.1" 200 474
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=shingu HTTP/1.1" 200 503
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=nhulunbuy HTTP/1.1" 200 465
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=thabazimbi HTTP/1.1" 200 487
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=attawapiskat HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=sangar HTTP/1.1" 200 487
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# ...
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=tessalit HTTP/1.1" 200 479
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kirakira HTTP/1.1" 200 493
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=waipawa HTTP/1.1" 200 485
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=ye HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=gariaband HTTP/1.1" 200 451
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kuching HTTP/1.1" 200 474
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=dali HTTP/1.1" 200 471
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=pastavy HTTP/1.1" 200 486
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=inhambane HTTP/1.1" 200 465
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=vallenar HTTP/1.1" 200 482
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=dingle HTTP/1.1" 200 489
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=sarkand HTTP/1.1" 200 486
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=ruidoso HTTP/1.1" 200 474
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=rocha HTTP/1.1" 200 490
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=cerrik HTTP/1.1" 200 462
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=rundu HTTP/1.1" 200 487
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=unai HTTP/1.1" 200 488
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=almaty HTTP/1.1" 200 503
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=malakal HTTP/1.1" 200 477
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=najran HTTP/1.1" 200 454
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=bogorodskoye HTTP/1.1" 200 491
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=torbay HTTP/1.1" 200 494
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=pocone HTTP/1.1" 200 504
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kracheh HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=touros HTTP/1.1" 200 466
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=matagami HTTP/1.1" 200 476
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kunming HTTP/1.1" 200 453
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=eyemouth HTTP/1.1" 200 468
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=grand%20forks HTTP/1.1" 200 460
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=ensenada HTTP/1.1" 200 484
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=san%20patricio HTTP/1.1" 200 473
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=krasnoarmeyskiy HTTP/1.1" 200 492
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kologriv HTTP/1.1" 200 490
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=camabatela HTTP/1.1" 200 487
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=beisfjord HTTP/1.1" 200 483
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=gaya HTTP/1.1" 200 441
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=nabire HTTP/1.1" 200 505
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=aklavik HTTP/1.1" 200 464
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=boyolangu HTTP/1.1" 200 492
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=nishihara HTTP/1.1" 200 470
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kjollefjord HTTP/1.1" 200 463
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=vichy HTTP/1.1" 200 476
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=den%20helder HTTP/1.1" 200 462
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=beipiao HTTP/1.1" 200 484
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=aripuana HTTP/1.1" 200 491
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=melfi HTTP/1.1" 200 464
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=sioux%20lookout HTTP/1.1" 200 462
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=batagay-alyta HTTP/1.1" 200 487
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=novobiryusinskiy HTTP/1.1" 200 502
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=stoyba HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=afrikanda HTTP/1.1" 200 513
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=amuntai HTTP/1.1" 200 502
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=kamenskoye HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=port-de-bouc HTTP/1.1" 200 466
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=innisfail HTTP/1.1" 200 493
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=muroto HTTP/1.1" 200 496
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=tabas HTTP/1.1" 200 486
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=el%20faiyum HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=boa%20vista HTTP/1.1" 200 475
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=roura HTTP/1.1" 200 467
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=chagda HTTP/1.1" 404 40
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): api.openweathermap.org:80
# working through to next data...
# DEBUG:urllib3.connectionpool:http://api.openweathermap.org:80 "GET /data/2.5/weather?appid=b7b88b3bd62a120ba8bef3514e063083&units=metric&q=imbituba HTTP/1.1" 200 463

# %%
   weather_dict = {
    "citylist": citylist,
    "country": country, 
    "lat": lat,
    "lon": lon,
    "temp": temp,
    "temp_max": temp_max,
    "cloudiness": cloudiness,
    "humidity": humidity,
    "windspeed": windspeed,
    "date": date,
    
}

# %%
weather_data = pd.DataFrame(weather_dict)
weather_data
# Out:
#              citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0                Lebu      CL -37.6167  -73.6500  17.99     17.99           1
# 1           Jamestown      US  42.0970  -79.2353  -3.10     -2.78          90
# 2              Barrow      US  71.2906 -156.7887 -23.00    -23.00          90
# 3             Dunedin      NZ -45.8742  170.5036   9.96      9.96          97
# 4            Tasiilaq      GL  65.6145  -37.6368   4.00      4.00          75
# ..                ...     ...      ...       ...    ...       ...         ...
# 547  Muroto-misakicho      JP  33.2833  134.1500  16.31     16.31          92
# 548             Tabas      IR  33.5959   56.9244  20.02     20.02          32
# 549         Boa Vista      BR   2.8197  -60.6733  32.00     32.00          75
# 550             Roura      GF   4.7263  -52.3274  26.55     27.22          90
# 551          Imbituba      BR -28.2400  -48.6703  27.00     27.00          75
#
#      humidity  windspeed        date
# 0          73       4.52  1614967499
# 1          91       8.32  1614967499
# 2          64       9.77  1614967500
# 3          81       2.14  1614967500
# 4          81       5.66  1614968031
# ..        ...        ...         ...
# 547        78       5.48  1614968344
# 548        44       8.04  1614968345
# 549        45       7.20  1614968345
# 550        83       3.60  1614968345
# 551        78       5.14  1614968347
#
# [552 rows x 10 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
#
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data.to_csv ('../apis_weather_vacation_challenge/weather_data.csv', index = False, header=True)

# %%
# Out:
# 0

# %%
output_data_file = "output_data/cities.csv"

# %%
for city in cities_print:
    try:
        response = requests.get(query_url + city).json()
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        lon.append(response['coord']['lon'])
        lat.append(response['coord']['lat'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        citylist.append(response['name'])
        windspeed.append(response['wind']['speed'])
    except (KeyError):
        print('Missing Data...')

# %%
print(weather_data)
# Out:
#              citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0             Ushuaia      AR -54.8000  -68.3000  16.00     16.00          20
# 1         East London      ZA -33.0153   27.9116  26.11     26.11          50
# 2              Torbay      CA  47.6666  -52.7314  -0.66      0.00          90
# 3       San Cristobal      VE   7.7669  -72.2250  33.00     33.00          40
# 4           Tuatapere      NZ -46.1333  167.6833  10.56     10.56          99
# ..                ...     ...      ...       ...    ...       ...         ...
# 561           Illapel      CL -31.6308  -71.1653  26.70     26.70           0
# 562          Almaznyy      RU  48.0448   40.0450  -2.00     -2.00          75
# 563           Yacuiba      BO -22.0380  -63.6797  29.22     29.22          51
# 564  Glenwood Springs      US  39.5505 -107.3248   0.73      4.44          90
# 565             Falam      MM  22.9167   93.6833  10.10     10.10          61
#
#      humidity  windspeed        date
# 0          41       9.77  1613158703
# 1          78       6.20  1613158904
# 2          86      11.32  1613158904
# 3          43       3.09  1613158800
# 4          93       0.89  1613158904
# ..        ...        ...         ...
# 561        40       4.42  1613159198
# 562        86      12.00  1613159273
# 563        43       3.02  1613159274
# 564        93       7.20  1613159172
# 565        49       1.32  1613159274
#
# [566 rows x 10 columns]

# %%
wdf= weather_data

# %%
len(wdf['temp'])
# Out:
# 566

# %%
 # create a data frame from cities, lat, and temp
weather_dict = {
    "citylist": citylist,
    "country": country, 
    "lat": lat,
    "lon": lon,
    "temp": temp,
    "temp_max": temp_max,
    "cloudiness": cloudiness,
    "humidity": humidity,
    "windspeed": windspeed,
    "date": date,
    
}
weather_data = pd.DataFrame(weather_dict)

# %%
weather_data
# Out:
#              citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0             Ushuaia      AR -54.8000  -68.3000  16.00     16.00          20
# 1         East London      ZA -33.0153   27.9116  26.11     26.11          50
# 2              Torbay      CA  47.6666  -52.7314  -0.66      0.00          90
# 3       San Cristobal      VE   7.7669  -72.2250  33.00     33.00          40
# 4           Tuatapere      NZ -46.1333  167.6833  10.56     10.56          99
# ..                ...     ...      ...       ...    ...       ...         ...
# 561           Illapel      CL -31.6308  -71.1653  26.70     26.70           0
# 562          Almaznyy      RU  48.0448   40.0450  -2.00     -2.00          75
# 563           Yacuiba      BO -22.0380  -63.6797  29.22     29.22          51
# 564  Glenwood Springs      US  39.5505 -107.3248   0.73      4.44          90
# 565             Falam      MM  22.9167   93.6833  10.10     10.10          61
#
#      humidity  windspeed        date
# 0          41       9.77  1613158703
# 1          78       6.20  1613158904
# 2          86      11.32  1613158904
# 3          43       3.09  1613158800
# 4          93       0.89  1613158904
# ..        ...        ...         ...
# 561        40       4.42  1613159198
# 562        86      12.00  1613159273
# 563        43       3.02  1613159274
# 564        93       7.20  1613159172
# 565        49       1.32  1613159274
#
# [566 rows x 10 columns]

# %%
type(weather_data)
# Out:
# pandas.core.frame.DataFrame

# %%
#weather_data.to_csv(index=False)
#http://localhost:8888/notebooks/Desktop/Resources/Homework/python-api-challenge/WeatherPy/WP_FINAL.ipynb
#weather_data.to_csv('weatherpy_data_.csv', index=False, header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humid100= (weather_data["humidity"]>100)
humid100.value_counts()
# Out:
# False    566
# Name: humidity, dtype: int64

# %%
#  Get the indices of cities that have humidity over 100%.

# NOTE:  No cities have a humidity value over 100

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# NOTE:  No cities have a humidity value over 100

# %%
wdf=weather_data
wdf
# Out:
#              citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0             Ushuaia      AR -54.8000  -68.3000  16.00     16.00          20
# 1         East London      ZA -33.0153   27.9116  26.11     26.11          50
# 2              Torbay      CA  47.6666  -52.7314  -0.66      0.00          90
# 3       San Cristobal      VE   7.7669  -72.2250  33.00     33.00          40
# 4           Tuatapere      NZ -46.1333  167.6833  10.56     10.56          99
# ..                ...     ...      ...       ...    ...       ...         ...
# 561           Illapel      CL -31.6308  -71.1653  26.70     26.70           0
# 562          Almaznyy      RU  48.0448   40.0450  -2.00     -2.00          75
# 563           Yacuiba      BO -22.0380  -63.6797  29.22     29.22          51
# 564  Glenwood Springs      US  39.5505 -107.3248   0.73      4.44          90
# 565             Falam      MM  22.9167   93.6833  10.10     10.10          61
#
#      humidity  windspeed        date
# 0          41       9.77  1613158703
# 1          78       6.20  1613158904
# 2          86      11.32  1613158904
# 3          43       3.09  1613158800
# 4          93       0.89  1613158904
# ..        ...        ...         ...
# 561        40       4.42  1613159198
# 562        86      12.00  1613159273
# 563        43       3.02  1613159274
# 564        93       7.20  1613159172
# 565        49       1.32  1613159274
#
# [566 rows x 10 columns]

# %%
#import matplotlib

# %%
#timedata= wdf["date"]

# %%
#timedata = matplotlib.dates.date2num(wdf['date'])
#matplotlib.pyplot.plot_date(dates, values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-799d88180922> in <module>
# ----> 1 timedata = matplotlib.dates.date2num(wdf['date'])
#       2 matplotlib.pyplot.plot_date(timedata)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/dates.py in date2num(d)
#     435         if not d.size:
#     436             return d
# --> 437         return _to_ordinalf_np_vectorized(d)
#     438
#     439
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2089             vargs.extend([kwargs[_n] for _n in names])
#    2090
# -> 2091         return self._vectorize_call(func=func, args=vargs)
#    2092
#    2093     def _get_ufunc_and_otypes(self, func, args):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2159             res = func()
#    2160         else:
# -> 2161             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2162
#    2163             # Convert args to object arrays first
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in _get_ufunc_and_otypes(self, func, args)
#    2119
#    2120             inputs = [arg.flat[0] for arg in args]
# -> 2121             outputs = func(*inputs)
#    2122
#    2123             # Performance note: profiling indicates that -- for simple
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/dates.py in _to_ordinalf(dt)
#     220         tzi = UTC
#     221
# --> 222     base = float(dt.toordinal())
#     223
#     224     # If it's sufficiently datetime-like, it will have a `date()` method
#
# AttributeError: 'numpy.int64' object has no attribute 'toordinal'

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# %matplotlib notebook
# Dependencies
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd
import requests
import time
import random
# Out:
# DEBUG:matplotlib.pyplot:Loaded backend nbAgg version unknown.

# %%
plt.title("Latitude v Temperature")
plt.scatter(x=wdf['temp'], y=wdf['lat'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
 # Plot out lat and temp
x_values = wdf['temp']
y_values = wdf['lat']
plt.scatter(x_values,y_values)
plt.xlabel('temperature')
plt.ylabel('latitude')
plt.show()
# This data shows that as the plots move farther from the equator it gets colder

# %% [markdown]
# # Fixing random state for reproducibility
# np.random.seed(19680801)
#
#
# N = 4
#
# x = (wdf['lat'])
#
# y = (wdf['humidity'])
# colors = np.random.rand(N)
# area = (7 * N ** 2)  # 0 to 15 point radii
#
# plt.scatter(x, y, s=area, c=colors, alpha=0.5)
# plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(wdf["humidity"], wdf["lat"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude v Humidity")
plt.ylabel("latitude")
plt.xlabel("humidity")
plt.grid(True)

# Save the figure
plt.savefig("HumidityandLatitude.png")

# Show plot
plt.show()
#Analysis:  This graph is a bit surprising as there seem to me more humid areas at high or northern latitudes then I would expect
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(wdf["lat"], wdf["cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude v Cloud")
plt.ylabel("cloudiness")
plt.xlabel("latitidue")
plt.grid(True)

# Save the figure
plt.savefig("latvcloud.png")

# Show plot
plt.show()
#This is an interesting graph as it shows a linear clumping of cloud cover but also makes sense since consistently cloudy regions exist colder areas
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(wdf["lat"], wdf["windspeed"], marker="o")

# Incorporate the other graph properties
plt.title("Latitude v Wind")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Lat v Wind.png")

# Show plot
plt.show()
#Analysis: Wind speed is increasing away from the equator and especially at higher latitudes
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# ## Linear Regression

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import csv
import matplotlib.pyplot as plt
from scipy import stats
import logging
logging.basicConfig(level=logging.DEBUG)

# Import API key
api_key="b7b88b3bd62a120ba8bef3514e063083"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

weather_data_to_load= "weatherpy_data_.csv"
weather_data = pd.read_csv(weather_data_to_load)

#weather_data_print_example= "weather_data_print.csv"
#weather_data_print = pd.read_csv(weather_data_print_example)

weather_north_to_load= "Weather_Data_North.csv"
wdn = pd.read_csv(weather_north_to_load)

weather_south_to_load= "Weather_Data_South.csv"
wds = pd.read_csv(weather_south_to_load)

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)


 # Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

query_url = f"{url}appid={api_key}&units={units}&q="

# %%
weather_data
# Out:
#              citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0             Ushuaia      AR -54.8000  -68.3000  16.00     16.00          20
# 1         East London      ZA -33.0153   27.9116  26.11     26.11          50
# 2              Torbay      CA  47.6666  -52.7314  -0.66      0.00          90
# 3       San Cristobal      VE   7.7669  -72.2250  33.00     33.00          40
# 4           Tuatapere      NZ -46.1333  167.6833  10.56     10.56          99
# ..                ...     ...      ...       ...    ...       ...         ...
# 561           Illapel      CL -31.6308  -71.1653  26.70     26.70           0
# 562          Almaznyy      RU  48.0448   40.0450  -2.00     -2.00          75
# 563           Yacuiba      BO -22.0380  -63.6797  29.22     29.22          51
# 564  Glenwood Springs      US  39.5505 -107.3248   0.73      4.44          90
# 565             Falam      MM  22.9167   93.6833  10.10     10.10          61
#
#      humidity  windspeed        date
# 0          41       9.77  1613158703
# 1          78       6.20  1613158904
# 2          86      11.32  1613158904
# 3          43       3.09  1613158800
# 4          93       0.89  1613158904
# ..        ...        ...         ...
# 561        40       4.42  1613159198
# 562        86      12.00  1613159273
# 563        43       3.02  1613159274
# 564        93       7.20  1613159172
# 565        49       1.32  1613159274
#
# [566 rows x 10 columns]

# %%
wdn= weather_data.loc[weather_data['lat'] > 0]
wdn
# Out:
#              citylist country      lat       lon   temp  temp_max  cloudiness  \
# 2              Torbay      CA  47.6666  -52.7314  -0.66      0.00          90
# 3       San Cristobal      VE   7.7669  -72.2250  33.00     33.00          40
# 5              Dikson      RU  73.5069   80.5464 -31.60    -31.60         100
# 7               Heihe      CN  50.2441  127.4902  -9.00     -9.00           0
# 8               Tiksi      RU  71.6872  128.8694 -24.28    -24.28           3
# ..                ...     ...      ...       ...    ...       ...         ...
# 559            Vuktyl      RU  63.8567   57.3094 -26.66    -26.66         100
# 560        Lavrentiya      RU  65.5833 -171.0000 -23.07    -23.07         100
# 562          Almaznyy      RU  48.0448   40.0450  -2.00     -2.00          75
# 564  Glenwood Springs      US  39.5505 -107.3248   0.73      4.44          90
# 565             Falam      MM  22.9167   93.6833  10.10     10.10          61
#
#      humidity  windspeed        date
# 2          86      11.32  1613158904
# 3          43       3.09  1613158800
# 5          88       4.98  1613158905
# 7          57       3.00  1613158905
# 8          90       0.38  1613158906
# ..        ...        ...         ...
# 559        88       0.85  1613159198
# 560        89       9.59  1613159198
# 562        86      12.00  1613159273
# 564        93       7.20  1613159172
# 565        49       1.32  1613159274
#
# [390 rows x 10 columns]

# %%
wdn= pd.DataFrame(wdn)
type(wdn)
# Out:
# pandas.core.frame.DataFrame

# %%
wdn.to_csv("Weather_Data_North.csv", encoding='utf-8', index=False)

# %%
weather_north_to_load= "Weather_Data_North.csv"
wdn = pd.read_csv(weather_north_to_load)

# %%
wds= weather_data.loc[weather_data['lat'] < 0]
wds
# Out:
#          citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0         Ushuaia      AR -54.8000  -68.3000  16.00     16.00          20
# 1     East London      ZA -33.0153   27.9116  26.11     26.11          50
# 4       Tuatapere      NZ -46.1333  167.6833  10.56     10.56          99
# 6    Punta Arenas      CL -53.1500  -70.9167  15.00     15.00           0
# 9           Vaini      TO -21.2000 -175.2000  27.00     27.00          40
# ..            ...     ...      ...       ...    ...       ...         ...
# 551       Calbuco      CL -41.7680  -73.1273  20.00     20.00           0
# 555       Waipawa      NZ -41.4122  175.5153  15.00     15.00           1
# 557  Saint-Pierre      RE -21.3393   55.4781  25.18     27.00          20
# 561       Illapel      CL -31.6308  -71.1653  26.70     26.70           0
# 563       Yacuiba      BO -22.0380  -63.6797  29.22     29.22          51
#
#      humidity  windspeed        date
# 0          41       9.77  1613158703
# 1          78       6.20  1613158904
# 4          93       0.89  1613158904
# 6          41       8.75  1613158905
# 9          89       2.57  1613158685
# ..        ...        ...         ...
# 551        60       5.14  1613159196
# 555        88       4.12  1613159197
# 557        69       8.75  1613159197
# 561        40       4.42  1613159198
# 563        43       3.02  1613159274
#
# [176 rows x 10 columns]

# %%
wds.to_csv("Weather_Data_South.csv", encoding='utf-8', index=False)

# %%
weather_south_to_load= "Weather_Data_South.csv"
wds = pd.read_csv(weather_south_to_load)

# %%
wds
# Out:
#          citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0         Ushuaia      AR -54.8000  -68.3000  16.00     16.00          20
# 1     East London      ZA -33.0153   27.9116  26.11     26.11          50
# 2       Tuatapere      NZ -46.1333  167.6833  10.56     10.56          99
# 3    Punta Arenas      CL -53.1500  -70.9167  15.00     15.00           0
# 4           Vaini      TO -21.2000 -175.2000  27.00     27.00          40
# ..            ...     ...      ...       ...    ...       ...         ...
# 171       Calbuco      CL -41.7680  -73.1273  20.00     20.00           0
# 172       Waipawa      NZ -41.4122  175.5153  15.00     15.00           1
# 173  Saint-Pierre      RE -21.3393   55.4781  25.18     27.00          20
# 174       Illapel      CL -31.6308  -71.1653  26.70     26.70           0
# 175       Yacuiba      BO -22.0380  -63.6797  29.22     29.22          51
#
#      humidity  windspeed        date
# 0          41       9.77  1613158703
# 1          78       6.20  1613158904
# 2          93       0.89  1613158904
# 3          41       8.75  1613158905
# 4          89       2.57  1613158685
# ..        ...        ...         ...
# 171        60       5.14  1613159196
# 172        88       4.12  1613159197
# 173        69       8.75  1613159197
# 174        40       4.42  1613159198
# 175        43       3.02  1613159274
#
# [176 rows x 10 columns]

# %% [markdown]
# ### HEMISPHEREIC WEATHER DATA

# %%
wdn
# Out:
#              citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0              Torbay      CA  47.6666  -52.7314  -0.66      0.00          90
# 1       San Cristobal      VE   7.7669  -72.2250  33.00     33.00          40
# 2              Dikson      RU  73.5069   80.5464 -31.60    -31.60         100
# 3               Heihe      CN  50.2441  127.4902  -9.00     -9.00           0
# 4               Tiksi      RU  71.6872  128.8694 -24.28    -24.28           3
# ..                ...     ...      ...       ...    ...       ...         ...
# 385            Vuktyl      RU  63.8567   57.3094 -26.66    -26.66         100
# 386        Lavrentiya      RU  65.5833 -171.0000 -23.07    -23.07         100
# 387          Almaznyy      RU  48.0448   40.0450  -2.00     -2.00          75
# 388  Glenwood Springs      US  39.5505 -107.3248   0.73      4.44          90
# 389             Falam      MM  22.9167   93.6833  10.10     10.10          61
#
#      humidity  windspeed        date
# 0          86      11.32  1613158904
# 1          43       3.09  1613158800
# 2          88       4.98  1613158905
# 3          57       3.00  1613158905
# 4          90       0.38  1613158906
# ..        ...        ...         ...
# 385        88       0.85  1613159198
# 386        89       9.59  1613159198
# 387        86      12.00  1613159273
# 388        93       7.20  1613159172
# 389        49       1.32  1613159274
#
# [390 rows x 10 columns]

# %%
wds
# Out:
#          citylist country      lat       lon   temp  temp_max  cloudiness  \
# 0         Ushuaia      AR -54.8000  -68.3000  16.00     16.00          20
# 1     East London      ZA -33.0153   27.9116  26.11     26.11          50
# 2       Tuatapere      NZ -46.1333  167.6833  10.56     10.56          99
# 3    Punta Arenas      CL -53.1500  -70.9167  15.00     15.00           0
# 4           Vaini      TO -21.2000 -175.2000  27.00     27.00          40
# ..            ...     ...      ...       ...    ...       ...         ...
# 171       Calbuco      CL -41.7680  -73.1273  20.00     20.00           0
# 172       Waipawa      NZ -41.4122  175.5153  15.00     15.00           1
# 173  Saint-Pierre      RE -21.3393   55.4781  25.18     27.00          20
# 174       Illapel      CL -31.6308  -71.1653  26.70     26.70           0
# 175       Yacuiba      BO -22.0380  -63.6797  29.22     29.22          51
#
#      humidity  windspeed        date
# 0          41       9.77  1613158703
# 1          78       6.20  1613158904
# 2          93       0.89  1613158904
# 3          41       8.75  1613158905
# 4          89       2.57  1613158685
# ..        ...        ...         ...
# 171        60       5.14  1613159196
# 172        88       4.12  1613159197
# 173        69       8.75  1613159197
# 174        40       4.42  1613159198
# 175        43       3.02  1613159274
#
# [176 rows x 10 columns]

# %% [markdown]
# ####  Northern Hemisphere - Temperature vs. Latitude Linear Regression

# %%
# start with values and labels
x_values = wdn['temp']
y_values = wdn['lat']
plt.scatter(x_values,y_values)
plt.xlabel('Temperature')
plt.ylabel('Latitude')
plt.title("Temperature&Latitude_Linear_Northern_Hemisphere")
plt.show()

x_values = wdn["temp"] 
y_values = wdn["lat"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
 # Print out the r-squared value along with the plot.

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.xlabel('Time')
#plt.ylabel('Temperature')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7527042243704315

# %%
x_values = wdn["temp_max"] 
y_values = wdn["lat"] 
plt.scatter(x_values,y_values) 
plt.xlabel("Temperature") 
plt.ylabel("Latitude") 
plt.grid(True)

plt.show()

# %% [markdown]
# #Analysis:  As the plots move northward the temperarure becomes less dense and much colder.

# %% [markdown]
# ####  Southern Hemisphere - Temperature vs. Latitude Linear Regression

# %%
# start with values and labels
x_values = wds['temp']
y_values = wds['lat']
plt.scatter(x_values,y_values)
plt.xlabel('Temperature')
plt.ylabel('Latitude')
plt.title('Latitude&Temperature_Southern_Hemisphere')
plt.show()

x_values = wds["temp"] 
y_values = wds["lat"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
 # Print out the r-squared value along with the plot.

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.xlabel('Time')
#plt.ylabel('Temperature')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.34812372692206994

# %%
x_values = wds["temp_max"] 
y_values = wds["lat"] 
plt.scatter(x_values,y_values) 
plt.xlabel("Temperature") 
plt.ylabel("Latitude") 
plt.grid(True)

plt.show()

# %% [markdown]
# #As we move towards the equator the temperature rises substantially at a total amount of over 25 degress Celcius.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# start with values and labels
x_values = wdn['humidity']
y_values = wdn['lat']
plt.scatter(x_values,y_values)
plt.xlabel('Humidity')
plt.ylabel('Latitude')
plt.show()

x_values = wdn["humidity"] 
y_values = wdn["lat"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


 # Print out the r-squared value along with the plot.

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.xlabel('Time')
#plt.ylabel(‘Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()


# Plot out humidity over time 
x_values = wdn["humidity"] 
y_values = wdn["lat"] 
plt.scatter(x_values,y_values)
plt.xlabel("humidity")
plt.ylabel("latitude") 
plt.grid(True)
plt.title('Humidity&Latitude_Northern_Hemisphere')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.09261397948294228

# %% [markdown]
# #Analysis: Although it is commonly thought that equatorial regions are more humid than northernly places, the graph here shows that there is a trend towards more humidity the farther north it goes.  The trend is not extreme, but signficant enough to be worth noting.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# start with values and labels
x_values = wds['humidity']
y_values = wds['lat']
plt.scatter(x_values,y_values)
plt.xlabel('humidityerature')
plt.ylabel('Latitude')
plt.show()

x_values = wds["humidity"] 
y_values = wds["lat"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


 # Print out the r-squared value along with the plot.

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.xlabel('Time')
#plt.ylabel(‘Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()


# Plot out humidity over time 
x_values = wds["humidity"] 
y_values = wds["lat"] 
plt.scatter(x_values,y_values) 
plt.xlabel("Humidity") 
plt.ylabel("Latitude") 
plt.grid(True)
plt.title("Humidity&Latitude_Southern_Hem_Linear")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.061369621904910354

# %% [markdown]
# #Analysis:  Although the humidity is pretty scattered, the trend increases slightly as the data points move to the equator.  However, there is more land in the northern hemisphere so that is a major factor when considering this data.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# start with values and labels
x_values = wdn['cloudiness']
y_values = wdn['lat']
plt.scatter(x_values,y_values)
plt.xlabel('cloudinesserature')
plt.ylabel('Latitude')
plt.show()

x_values = wdn["cloudiness"] 
y_values = wdn["lat"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


 # Print out the r-squared value along with the plot.

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.xlabel(‘L’atitude)
#plt.ylabel(‘cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()


# Plot out cloudiness over time 
x_values = wdn["cloudiness"] 
y_values = wdn["lat"] 
plt.scatter(x_values,y_values) 
plt.xlabel("Cloudiness") 
plt.ylabel("Latitude")
plt.grid(True)
plt.title("Cloudiness&Latitude_Northern_Hem_Linear")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.03461969997817402

# %% [markdown]
# #Analysis: There is more cloud cover at the poles but only slightly

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# start with values and labels
x_values = wds['cloudiness']
y_values = wds['lat']
plt.scatter(x_values,y_values)
plt.xlabel('cloudinesserature')
plt.ylabel('Latitude')
plt.show()

x_values = wds["cloudiness"] 
y_values = wds["lat"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


 # Print out the r-squared value along with the plot.

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.xlabel(‘L’atitude)
#plt.ylabel(‘cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()


# Plot out cloudiness over time 
x_values = wds["cloudiness"] 
y_values = wds["lat"] 
plt.scatter(x_values,y_values) 
plt.xlabel("Cloudiness") 
plt.ylabel("Latitude") 
plt.title("Cloudiness_&_Latitude_Linear_Southern_Hem")
plt.grid(True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.07384624606654731

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# start with values and labels
x_values = wdn['windspeed']
y_values = wdn['lat']
plt.scatter(x_values,y_values)
plt.xlabel('windspeederature')
plt.ylabel('Latitude')
plt.show()

x_values = wdn["windspeed"] 
y_values = wdn["lat"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


 # Print out the r-squared value along with the plot.

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.xlabel(‘Latitude)
#plt.ylabel(‘windspeed')
print(f"The r-squared is: {rvalue**2}")
plt.show()


# Plot out windspeed over time 
x_values = wdn["windspeed"] 
y_values = wdn["lat"] 
plt.scatter(x_values,y_values) 
plt.xlabel("Wind Speed") 
plt.ylabel("Latitude") 
plt.grid(True)
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.012450921892020477

# %% [markdown]
# #Analysis:  The wind speed increases slight as we move towards the pole.  Not as much as I would have thought but then again, the equatorial area does have the phenomenon of hurricanes and such so it would be interesting to see the data if we removed extreme weather events and plotted it every day over the span of a year.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# start with values and labels
x_values = wds['windspeed']
y_values = wds['lat']
plt.scatter(x_values,y_values)
plt.xlabel('windspeederature')
plt.ylabel('Latitude')
plt.show()

x_values = wds["windspeed"] 
y_values = wds["lat"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


 # Print out the r-squared value along with the plot.

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.xlabel(‘Latitude)
#plt.ylabel(‘windspeed')
print(f"The r-squared is: {rvalue**2}")
plt.show()


# Plot out windspeed over time 
x_values = wds["windspeed"] 
y_values = wds["lat"] 
plt.scatter(x_values,y_values) 
plt.xlabel("Wind Speed") 
plt.ylabel("Latitude") 
plt.grid(True)
plt.title("Southern_Hemisphere_WindSpeed(mph)vLatitude_Linear_Regression")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.014399496789090709

# %% [markdown]
# #Analysis:  The wind speed increases slighty as we move towards the south pole but again, if we removed extreme weather events, over the course of the year instead of a day, it would be interesting so note the differences.
